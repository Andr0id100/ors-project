# %%
# %%system
# rm /scratch/ors -r
# mkdir /scratch/ors
# mkdir /scratch/ors/dmg
# cp ~/ors-project/data.tar.gz /scratch/ors
# tar -xzvf /scratch/ors/data.tar.gz --directory /scratch/ors/
# mv /scratch/ors/patches_256_v2/ /scratch/ors/clr
# Out:
# ['patches_256_v2/',
#  'patches_256_v2/47241882b3ec18350d5cf9f2b2ae7126.png',
#  'patches_256_v2/f3bc77c7c77490d57feb757311ec78d0.png',
#  'patches_256_v2/853c1077ca1750b4a4f13fc5bf49c0d1.png',
#  'patches_256_v2/271b8741f4669704c795e04c8dc054b9.png',
#  'patches_256_v2/33e98642af577a500dffd3936629ebe7.png',
#  'patches_256_v2/44a924d539458dd0c490340ab9a611c4.png',
#  'patches_256_v2/271b38b5c8419709160b5365bee967a5.png',
#  'patches_256_v2/8d899ea6c7ccc62206e4243b8ab40fbe.png',
#  'patches_256_v2/ecf50e585ecbe7a69a26807143e56c4c.png',
#  'patches_256_v2/4f770737e533fefeb5e02d8010dbfad4.png',
#  'patches_256_v2/dba15f7ceea4841b2ec46045d6d6b71c.png',
#  'patches_256_v2/5fb27c8713f6c4d03814ac853ff47acf.png',
#  'patches_256_v2/77a70f7a45892ec3cfb60138621567ee.png',
#  'patches_256_v2/23a476f783cc6effd207ae81926dd8f2.png',
#  'patches_256_v2/4c061e4b40febe21e4e70b6b7f861790.png',
#  'patches_256_v2/b366346cb994faf4e6a562dab306cf02.png',
#  'patches_256_v2/c7114d94283ad15c483cba708012b877.png',
#  'patches_256_v2/4d2ad927c068c4f64205c532e2f23862.png',
#  'patches_256_v2/cdaa86843c6005448f1eaee0308f19df.png',
#  'patches_256_v2/b969248a27dda2788a4a99761d191073.png',
#  'patches_256_v2/043be962ff229d3e072b102e886517fd.png',
#  'patches_256_v2/8860dfcffebd5f87978d301128e3a698.png',
#  'patches_256_v2/85e7226f13fc48a2c78b787e7229dbbd.png',
#  'patches_256_v2/9e4e1d38b1ee00a83c72b03b956755bb.png',
#  'patches_256_v2/24374c641cc64addeeb7c852d7269d79.png',
#  'patches_256_v2/7cd13dc23d15daa73724dd9eef66143d.png',
#  'patches_256_v2/22bda77c3fd8d1a0a6407e641d5547fd.png',
#  'patches_256_v2/1378d4c00f6431175f6f5b8b4d828ffd.png',
#  'patches_256_v2/4c945bfb2ac36aa5e3d4e8060e4a8cae.png',
#  'patches_256_v2/a30f575048820f04c8a11fa8eada3bcf.png',
#  'patches_256_v2/8a64e219b00ad72580537730a1f8ae7f.png',
#  'patches_256_v2/e1e3ce15a6b61eaa1487c35076f9105f.png',
#  'patches_256_v2/de0d55f6786fec240d5d29f42a5fd44e.png',
#  'patches_256_v2/5b3582de4d04e2bedc73b64b80cf1890.png',
#  'patches_256_v2/835de0b89fac6a8a59708e87bc29b4b5.png',
#  'patches_256_v2/48ba0d03620a2cf1528bf75f15c00802.png',
#  'patches_256_v2/190689598c40339081e230ed3e87e0a2.png',
#  'patches_256_v2/4592211be7a9ce9071f7d5b029380dc6.png',
#  'patches_256_v2/81e5d50729d1b69ba40af9bcd99b2f86.png',
#  'patches_256_v2/d6891ca2673cdb28e1a400b255d32b26.png',
#  'patches_256_v2/dbc2def2475b49e0a066064ea9744e90.png',
#  'patches_256_v2/13d6ae883eeff06706467d483d6a8e2b.png',
#  'patches_256_v2/c91d4301f0ebe7096ace7564a4e7a91c.png',
#  'patches_256_v2/4d1cb6f405979b99a7b45164e654f04b.png',
#  'patches_256_v2/fb65debb65e166649f059238fa9384b4.png',
#  'patches_256_v2/fd26cb742091f1f6f0f84c4547337f96.png',
#  'patches_256_v2/93e625f894ac6475991c1d6845a15bf9.png',
#  'patches_256_v2/9101d6f5bdf2cb58c501c3ba363904e6.png',
#  'patches_256_v2/c1a9477d0dceaec8ddc940992420e12d.png',
#  'patches_256_v2/3239a4d563d4a9590f6507f00d39a519.png',
#  'patches_256_v2/9f2a5216dbb6a9a861869759c414c5ca.png',
#  'patches_256_v2/d25d80e7586fb0ae3d0cf367d6ba937b.png',
#  'patches_256_v2/ef1551d7bd8876f80da6eb15edbee668.png',
#  'patches_256_v2/356d388590239910e3ee4067eebd164c.png',
#  'patches_256_v2/bff5312b6a2b70a86a8564744bed17d1.png',
#  'patches_256_v2/42050e354c6e6208804f219799518bef.png',
#  'patches_256_v2/740352b8842386a790a8fe12a1bed6f4.png',
#  'patches_256_v2/4f12111ceb239b8e4dac91149a235a1b.png',
#  'patches_256_v2/28b79d77886f892356e8ffeb87accb1d.png',
#  'patches_256_v2/bde0afb1588cb3d9971ffe91a874b60f.png',
#  'patches_256_v2/b6d3b3bbb7f6ac67cef9fcaba7fcd362.png',
#  'patches_256_v2/731f2e58a16743762b907cd936960176.png',
#  'patches_256_v2/b9bcadbe8c3dfb7a95679fa45ed6f047.png',
#  'patches_256_v2/38a0ca07f810c57f634f10f4b574bfd8.png',
#  'patches_256_v2/c232e8fd976f48e56bba93088f196d16.png',
#  'patches_256_v2/47c5d3c8a898e63cf9e6f8491bbd7cff.png',
#  'patches_256_v2/6baa370b571650da6658e9f62e65825b.png',
#  'patches_256_v2/f452f41820ede1d6668e9ee0e83c1a8a.png',
#  'patches_256_v2/a3ae27fd74620bd75edece0a2cd6caf4.png',
#  'patches_256_v2/d45ee04702b4e617fe301d77a1b2df70.png',
#  'patches_256_v2/14eba537694440ac8acdd9cb0e489f2d.png',
#  'patches_256_v2/72c31ba2d97e9bd2ffffdfc26d3f4aea.png',
#  'patches_256_v2/edeb9b2b8880c62e346858fe3239046f.png',
#  'patches_256_v2/7dfe25889f86fc001c9b7b65a9685dea.png',
#  'patches_256_v2/d5435dc1c7e4dabd6a697af9075c3580.png',
#  'patches_256_v2/e7149db79090c0a3edb2ac4dedd2a254.png',
#  'patches_256_v2/6a1dfbfb6425b96f49c6922a62e9f300.png',
#  'patches_256_v2/ccd97844f45c07e64047b4457878f2ee.png',
#  'patches_256_v2/48dff6223756cebe8eb100ad930f4c55.png',
#  'patches_256_v2/86d2cc2503512f78a9b95491ebdf6e0b.png',
#  'patches_256_v2/9697450d3bebbba5d1ef80ffd651f63f.png',
#  'patches_256_v2/38a5c9d4d1670b60412e93d8fda00f66.png',
#  'patches_256_v2/ea629e6ce8dd27a712ad5656089de017.png',
#  'patches_256_v2/89d1d8ce364bb726655087dcdddc67ef.png',
#  'patches_256_v2/c888dc6fb2ebccf3fbcfd4a1628f3b24.png',
#  'patches_256_v2/7eebf234d7f5448274d7c4de19cd3126.png',
#  'patches_256_v2/e9a9efc45201a26c7431bee448b20b71.png',
#  'patches_256_v2/f9a546b70d97d9d9419bf9cf337f193c.png',
#  'patches_256_v2/0170f037eb04b4ffb832331320d6e2b6.png',
#  'patches_256_v2/bd030eaae47e298757c8fd0830d714d4.png',
#  'patches_256_v2/f29cb5c36b183487fa6731e670d279e9.png',
#  'patches_256_v2/d75cf143c854ca3ff817b0198975a573.png',
#  'patches_256_v2/c8ad8aadae68ceb113826f491f166c57.png',
#  'patches_256_v2/87b0528c2abd684766bfa1683e433e61.png',
#  'patches_256_v2/89db6b7585400cb03bd2d3f3bfa31599.png',
#  'patches_256_v2/d001e09157ec6d10a7c8edb896885c84.png',
#  'patches_256_v2/79b99a614b087d1193f6a0fdb57e44b7.png',
#  'patches_256_v2/a6d939002b70c2432a0e816f3c6a985b.png',
#  'patches_256_v2/a7fc77515bb893a7e29b22d154832a07.png',
#  'patches_256_v2/70d22fcc664402fb55e94fad14e74866.png',
#  'patches_256_v2/587c7cfa8fe8f32644b4e0c5f52d5450.png',
#  'patches_256_v2/e02ea162d588b13a7604dacb01f2d0f2.png',
#  'patches_256_v2/7830bbd5305775757308ca13c7803db8.png',
#  'patches_256_v2/7ca1b4dd4694c9c5599d71b1b7865b55.png',
#  'patches_256_v2/775a971c6a5768fdfd91bda6dbe71677.png',
#  'patches_256_v2/5e9e5d30cf036e13cac7c59b8503e790.png',
#  'patches_256_v2/9d193b385b28f1d207ee1d139ad8b50f.png',
#  'patches_256_v2/be5229c1e187ad06e4d915ee7d3c3b31.png',
#  'patches_256_v2/53ffceb0e53b420dfc5d7f4f27b9809d.png',
#  'patches_256_v2/8fa21418fb7895f4417a71b0a52a857e.png',
#  'patches_256_v2/7eec3d615998252c899b31bfbe2dbc94.png',
#  'patches_256_v2/f5385de698355b2b47fb160e809c5eee.png',
#  'patches_256_v2/3d73ac97c9458c7174fed5cbdb1d86bd.png',
#  'patches_256_v2/775f1173a86baf903edd9dc41a05ac53.png',
#  'patches_256_v2/756644ea63722fb5b96e869885141ebf.png',
#  'patches_256_v2/c9de892c95053c2501c35337ae729926.png',
#  'patches_256_v2/8e1d0ab1076266754c1e21d9b18b109a.png',
#  'patches_256_v2/09a29c0148c55b0f68aa0877febb9f90.png',
#  'patches_256_v2/2cd1f2ff53230d4f354f19ea2c4077c0.png',
#  'patches_256_v2/0e58236181a27d75557cc783b3bf2bd8.png',
#  'patches_256_v2/f2d79fde0ba6f863d6b5cea39dcad8dc.png',
#  'patches_256_v2/5421fd7b536cf551694b292c9c816a8a.png',
#  'patches_256_v2/087e5e20d90d93f81d69890fd3fa1d22.png',
#  'patches_256_v2/eb9512eec73e1935bcaf8dd206dd39ab.png',
#  'patches_256_v2/23485a91d449bfde50aeb6679fec2ec7.png',
#  'patches_256_v2/437fe9c64bc4c271e7101250dd7ae683.png',
#  'patches_256_v2/466a5be32b393dfafe487635f18a779a.png',
#  'patches_256_v2/2be143503677a69d4f294ab5f7e76869.png',
#  'patches_256_v2/fc9bb8d5d7e2ec37eb76d69c0ef33e46.png',
#  'patches_256_v2/31b1462e14c8cf3b338bc74029a09de1.png',
#  'patches_256_v2/78e6c5494df4d88818d30311a682de95.png',
#  'patches_256_v2/6183a98553648e193ed7237f1527cd07.png',
#  'patches_256_v2/12587d14d74eed59658a5e715eda1eae.png',
#  'patches_256_v2/68f5637c94d61fa233048af809dc1f41.png',
#  'patches_256_v2/f1fc62666ec438949001cf2e409870a4.png',
#  'patches_256_v2/6a77fb46c29197572d6964865b5ea8f6.png',
#  'patches_256_v2/53b99abfd38c9c7e8bfea7aa73fc6753.png',
#  'patches_256_v2/df632b8b585418bd27f9355461479440.png',
#  'patches_256_v2/8f0106f8f8d2e441abcd65cc8f8efb34.png',
#  'patches_256_v2/7943c0a042a00ab9c4eba6afbd2c3f9b.png',
#  'patches_256_v2/abd8a77a00b60595512c30b4b774f068.png',
#  'patches_256_v2/9c54b2261d9fdaa96813d1be31a3c676.png',
#  'patches_256_v2/3b2c7dd820f49ae80f35c840e39c53ad.png',
#  'patches_256_v2/e6b5ec4c96e5a410f95fd8908402b7c3.png',
#  'patches_256_v2/f446ffac049d441950f67c2249ed627b.png',
#  'patches_256_v2/f8d32bf2aee2163a2bd7bb075fa08d77.png',
#  'patches_256_v2/a76003630ddf466d1755967926763a88.png',
#  'patches_256_v2/2c5b83ea53a7c4aa87b313fcad9e2b43.png',
#  'patches_256_v2/95460871bc54acb6be134990f74f7a9d.png',
#  'patches_256_v2/4efb98fefb2d50c734f068a8e9bfa611.png',
#  'patches_256_v2/7832164a5b732f8c8b63d540269164df.png',
#  'patches_256_v2/3e386262f2aa0fe9842c3106492b95d6.png',
#  'patches_256_v2/7f6cbdc3dabbbd007a7c8b4607b90688.png',
#  'patches_256_v2/93704e9fab3676c2ced4c2473967c8e1.png',
#  'patches_256_v2/3088e2909e15694426c09cdc223d216f.png',
#  'patches_256_v2/21e7313a1aa42fe923deacbe2626de84.png',
#  'patches_256_v2/54cca5e50f55dc23a4d259d113d2e405.png',
#  'patches_256_v2/b54ae6b1ba269a12c65a4edbe27b5bb9.png',
#  'patches_256_v2/62cab6b7ddd0d227278590e8560b6cc9.png',
#  'patches_256_v2/cc489219851fe5bcc28de84f7b970046.png',
#  'patches_256_v2/142f86545e84f4b579b2ebf55e2c932c.png',
#  'patches_256_v2/dd54cb7904946541ace62d0667f62c91.png',
#  'patches_256_v2/b633500b37efa8b9f45f8bac20c72e39.png',
#  'patches_256_v2/4ed9cd7339a07f93194359d96df522b0.png',
#  'patches_256_v2/c78ec2d7ef32e8905203dbec17e81746.png',
#  'patches_256_v2/59fd905ed4d634f88f8f9d084af437e3.png',
#  'patches_256_v2/2c57d78a173e68d3a8f00151496cfbbd.png',
#  'patches_256_v2/2b2767b31bdf35a70c1923953cdfe446.png',
#  'patches_256_v2/3ce5a4276c6ae69be5a696ba3304ff88.png',
#  'patches_256_v2/8d3197ccb292ac5d9d30d9c5f298f6e0.png',
#  'patches_256_v2/e91a2e652641d7527590d19f68d72338.png',
#  'patches_256_v2/43a8f857a11709cc288b94c81846307b.png',
#  'patches_256_v2/c385c1f98482bfa4f5ebb393af1478be.png',
#  'patches_256_v2/25af53adba554b8bcbf3c9e474ac51d8.png',
#  'patches_256_v2/c02325593a5e88ef68bf66eaf0bdc8ce.png',
#  'patches_256_v2/286e8b69c79b19be63730f99f3364c2d.png',
#  'patches_256_v2/aaee8928037ece3683d0be6a86d097b6.png',
#  'patches_256_v2/dfd9223c9b90382435614ec86e18a826.png',
#  'patches_256_v2/779f1112ede078f230f005b7eb432323.png',
#  'patches_256_v2/8d695d57f6ac6c42179ae369bc8a5afc.png',
#  'patches_256_v2/f8e46fa23c4d3a2ac660b4f76e3daa97.png',
#  'patches_256_v2/8f26fcb809afb42b0968cc84dc194eff.png',
#  'patches_256_v2/fc4b73b6ed2947e942aa7ae5328f4270.png',
#  'patches_256_v2/62e7aa65443224468b6a8ba678aa9c19.png',
#  'patches_256_v2/10c3fa2626298b3b3761a35b15c98bce.png',
#  'patches_256_v2/1a2f13b0c004d1c78756dac5e6ae4b05.png',
#  'patches_256_v2/39a859293eeb3fedf22408af5c8f422a.png',
#  'patches_256_v2/f2ed34ab89f16299f3ca7cd18f43c2ac.png',
#  'patches_256_v2/c253fb50532f7039dd8688d18e8b09ba.png',
#  'patches_256_v2/4deb1a0142b10b522613da12fc02f235.png',
#  'patches_256_v2/e1e6646874c5870f200b25a8d40073d4.png',
#  'patches_256_v2/2d3d0b68bb37f07ab5dc055f2630ab92.png',
#  'patches_256_v2/e469cc642d9136270c67e78c1e825205.png',
#  'patches_256_v2/7c3b161662a15a9ddd77b97ca54aa757.png',
#  'patches_256_v2/15412950f0e52e2385179db91d9ad35d.png',
#  'patches_256_v2/bfa716ae1fa131a4ba6d47beb9b4ea92.png',
#  'patches_256_v2/4585534a5876db6775e25e480b1d5013.png',
#  'patches_256_v2/53bc41cec1967dec95a939b1cd0880db.png',
#  'patches_256_v2/2df4392ae6779ab250f05ff9dfa9f2c1.png',
#  'patches_256_v2/059524746fcf7a26e9c56484b555ab70.png',
#  'patches_256_v2/ce16af122ec93ae00be706e40fba6ea6.png',
#  'patches_256_v2/a7906beda74772a0d9feb9a856e52da2.png',
#  'patches_256_v2/f3ff80a6dfc6158ab3c62c7257348604.png',
#  'patches_256_v2/030aa2874d781835dd1ddd525e974a72.png',
#  'patches_256_v2/b88c793a9fbd33e0a661d12386401d0e.png',
#  'patches_256_v2/e5c7e5e33f7857be02c6a51374571013.png',
#  'patches_256_v2/b3a4a4d444feb4a91aa9284f38bc5a2f.png',
#  'patches_256_v2/e735c1be13843f49e26899ed3bacf873.png',
#  'patches_256_v2/8f497be90925140735cca7709682a479.png',
#  'patches_256_v2/408558367a4cd1f104e4860037bddcc3.png',
#  'patches_256_v2/37037e3f3f7e3090deb7f43e6353c191.png',
#  'patches_256_v2/a1f53d83a82baafc4475b38ad0e02a34.png',
#  'patches_256_v2/b1fa72a24cc0f9db91031e886aa323bb.png',
#  'patches_256_v2/affd1e0038ee17d623300e51378a01a2.png',
#  'patches_256_v2/cd5928db6a64f26bdb4c947ebe28e949.png',
#  'patches_256_v2/e8bf21bc039186b4fcac38f2d1d91fdb.png',
#  'patches_256_v2/c943989ab64df7b8d0b17a38bf689524.png',
#  'patches_256_v2/006ec8343c1edd06cc7863875aa2a2ad.png',
#  'patches_256_v2/d2c43ddda8d67514d0bf7e341aa2baf3.png',
#  'patches_256_v2/7d9480d903a52a43edd7c2658248e861.png',
#  'patches_256_v2/c1d03fd7831303dc9be259da4599298f.png',
#  'patches_256_v2/2f8d177c1519f3c0a898cac4b75f7d06.png',
#  'patches_256_v2/822677c002a60e34ae4686f6fccc7d15.png',
#  'patches_256_v2/8c7728abdaaee1783aa05c8e6ed4a4a4.png',
#  'patches_256_v2/c04417837d585726c131233b05fe912c.png',
#  'patches_256_v2/773a3c725a97435791aed3e4db9eba3f.png',
#  'patches_256_v2/38e2e43a84c00df923b59913c5919a61.png',
#  'patches_256_v2/270deae2435d15c4f344802620948571.png',
#  'patches_256_v2/e5604b9e504ad4a00398c815b6797b17.png',
#  'patches_256_v2/df98aecd72152f51107918f589a791b2.png',
#  'patches_256_v2/fa92d0e0083d44fd77fc5eabfd7af915.png',
#  'patches_256_v2/9fc96aaa93000e5defebca19c311f6ce.png',
#  'patches_256_v2/21e92fe1beca7b50fa09db69241fdd20.png',
#  'patches_256_v2/185ce9dc8bd33e138f36c8cfe3951d0f.png',
#  'patches_256_v2/380420d5db71ef55558efd11c6c5f0de.png',
#  'patches_256_v2/b31e232cc385358246a9eaa6fcc6d856.png',
#  'patches_256_v2/b93900fc44c1320d1ce2ee7f385ead2e.png',
#  'patches_256_v2/21a186a7925ce5cceb71c3c9f2d3cc02.png',
#  'patches_256_v2/ad3022bbcb0af107590217b6227bb4de.png',
#  'patches_256_v2/7afc635ff6ce25d35ff4625945a722a7.png',
#  'patches_256_v2/9d943f363d30d2821133fac687a6b16b.png',
#  'patches_256_v2/de90d2a349a9e7380135eb2bf0dfcfc4.png',
#  'patches_256_v2/c855a5458d9866fc7591656d109a9359.png',
#  'patches_256_v2/bdcf715dad908ea4f7972fde0a05d8d6.png',
#  'patches_256_v2/8b2962b6c75df5907abb436e044ac1c5.png',
#  'patches_256_v2/da07de351f3c8b7eddee6957c97f1cac.png',
#  'patches_256_v2/55f19c5c1b3c555aec3dbbd356c4a305.png',
#  'patches_256_v2/69033b0e7ac3ab7850f456e3ee50ab31.png',
#  'patches_256_v2/fa4d085da63c57f2a15caf1f84376f01.png',
#  'patches_256_v2/9e0e2bcc115b7e6f3d5fb3f3e1fb179e.png',
#  'patches_256_v2/5dd3e9e81aeb1f7ba20d0cc776122dc2.png',
#  'patches_256_v2/f60a02cc85117a0886670fae143e22f1.png',
#  'patches_256_v2/dfccdf338f69296defb489b75dff0c9e.png',
#  'patches_256_v2/188972b5a0b53f6104e8a1d24a8e9560.png',
#  'patches_256_v2/8bed3d50c92bf9c8800694f846fe8133.png',
#  'patches_256_v2/dc0664e3a1c2edd090032ea1918658be.png',
#  'patches_256_v2/6922869395c7dbafdcd11d42007bbc1a.png',
#  'patches_256_v2/61e73520dd4aca8115d4b98deef4510d.png',
#  'patches_256_v2/2cb7380fbf8290bcd54cc5708dc8ab6f.png',
#  'patches_256_v2/c6509aebbc13167b2594c93b4383035a.png',
#  'patches_256_v2/92413a908a879b94687bea94ae97e07f.png',
#  'patches_256_v2/b21ff0d2208ebd3b43b8c2d42ab26080.png',
#  'patches_256_v2/9ef9a6609482204cf2df8b6ac88e7916.png',
#  'patches_256_v2/77fc692b05f928829dbf0bb17e2f90d5.png',
#  'patches_256_v2/b4886b9693eeb07d3952a95748b8dbe5.png',
#  'patches_256_v2/32f4ae0fecbbc1b8ab41367d9c3460ec.png',
#  'patches_256_v2/8d2c79ca885a808a4949579f4d6e08fd.png',
#  'patches_256_v2/ced07306faf4f6a3038a5c796a8f752e.png',
#  'patches_256_v2/bbb55889cab7df07fd0c76c4596a03c7.png',
#  'patches_256_v2/93dfa8044449886efedcf456c9b1f425.png',
#  'patches_256_v2/01fa9dbc4b18405fe5939339092b364c.png',
#  'patches_256_v2/c23d09c0604a2ce7b9d74dc6346bf35c.png',
#  'patches_256_v2/76c51add7af4b8755bb4b686135d6cf0.png',
#  'patches_256_v2/dd92eb9cd48683a8886afb00781a0366.png',
#  'patches_256_v2/44f0f8124ea372ff4692476f7e887efb.png',
#  'patches_256_v2/2334e14f78e9e30f544a187076dd6607.png',
#  'patches_256_v2/f5e367b4539258e97ea86c8ac0e17d85.png',
#  'patches_256_v2/0f1cdae021043fbf509e1da77172a1d8.png',
#  'patches_256_v2/053dd76ca19f9b3f5b871dec74fa8af0.png',
#  'patches_256_v2/e9da340f928dfa68391de8b7499fdd97.png',
#  'patches_256_v2/187837739ca64f5e55b0f2531ba54c21.png',
#  'patches_256_v2/047f66c18f25ac10c8653d8bc2357a23.png',
#  'patches_256_v2/d2936b4235e42be20e43ae976afd1146.png',
#  'patches_256_v2/224878900d0b784914cb67b71ffa7be9.png',
#  'patches_256_v2/cf0854fb46e78bb3f87b18d10e443772.png',
#  'patches_256_v2/e05b48af3b13dabb532b30484d811627.png',
#  'patches_256_v2/e31bf2e539ac2d32ed194455eae2c8aa.png',
#  'patches_256_v2/fd1e6480eb2c65a5b65997329b45be01.png',
#  'patches_256_v2/776142835688292e48edd5cc36c1cf28.png',
#  'patches_256_v2/cd14c46becf1339609399ac8055c4d1e.png',
#  'patches_256_v2/53c8e55574d03bd7f309bbf99eb3c20f.png',
#  'patches_256_v2/ef659d927dbf5ef5c538cfccc7e6961b.png',
#  'patches_256_v2/ef49deb78de83592859d1287d55fb9ab.png',
#  'patches_256_v2/8b5d497b8b3a3d7557d267c92115e350.png',
#  'patches_256_v2/62b6a9969b02b80e66c06ed95af73131.png',
#  'patches_256_v2/cf74a4329318d76f1cbb493c816964a9.png',
#  'patches_256_v2/ee5f09a6a04a45a4a92a6a22c7188f31.png',
#  'patches_256_v2/f469df9b6d6e3bc1354e721c464d748e.png',
#  'patches_256_v2/99be1c14b4e5499e670d2263bfb25913.png',
#  'patches_256_v2/da8c5ec13335be832c0a817e6d89da85.png',
#  'patches_256_v2/d660db5c0659039850680833570f449e.png',
#  'patches_256_v2/d37587bb256fb2481aab2768968b1648.png',
#  'patches_256_v2/439ce81f3cb035c6e6ec2318d2800995.png',
#  'patches_256_v2/9aa1907a3402b4ef67617da34c89f1d5.png',
#  'patches_256_v2/0f42310001bb429cdce63431d1d459c0.png',
#  'patches_256_v2/0d0b117720cad8de7f5da9c3bb03d252.png',
#  'patches_256_v2/2e49f0fd665db3b3bd8c09749f013123.png',
#  'patches_256_v2/45ad81bc27a799a4823635cbd6f71ce0.png',
#  'patches_256_v2/7a3948c16dd018d716d4705e44638cec.png',
#  'patches_256_v2/31d4343dc6e90a8370272195313b407e.png',
#  'patches_256_v2/45b55a97de7d00111d8285f06e7987d8.png',
#  'patches_256_v2/875a2ba14ad5ae4bddab1841658c5a65.png',
#  'patches_256_v2/c3d9322c1cd37aafa7f930d6bacfb6a5.png',
#  'patches_256_v2/b1979d098b09c229c5e1b8ab19225525.png',
#  'patches_256_v2/4816149d103476b239bc762ecfee38e7.png',
#  'patches_256_v2/c08a6ec55456bf530d646652a83ceb99.png',
#  'patches_256_v2/62afec7e29c7b628b8099b5ebed9f9e7.png',
#  'patches_256_v2/c1bb069de12befa71af40ef694b0f02c.png',
#  'patches_256_v2/9205e7442ef60224ed1f3edb7751d10a.png',
#  'patches_256_v2/7444a89864222147456385944d7151e6.png',
#  'patches_256_v2/116b3ef60c3e4e80cb65e642fc7952af.png',
#  'patches_256_v2/e74a0f50f04bc3b8a132b613bc14b310.png',
#  'patches_256_v2/1b26168177dd8fdf4913f8f2ce1f680b.png',
#  'patches_256_v2/2c1a9632f6bcd368c46cc5c60641081b.png',
#  'patches_256_v2/e7d9d5cfa23752b66d36afee85a697db.png',
#  'patches_256_v2/91d225d0940950b5c52398fb221924d2.png',
#  'patches_256_v2/1f30cf1eec8696cd444762b2638e6c38.png',
#  'patches_256_v2/e2de2632dcab9edd2038e072589da23d.png',
#  'patches_256_v2/64e1018ed8f8270b01161d82664a92b7.png',
#  'patches_256_v2/188f535068c3740e71045ca6f780ac4d.png',
#  'patches_256_v2/4ce57ea744d06027ea8fab9977aee44e.png',
#  'patches_256_v2/649118de3092a10bc5d8bfaeeb63f94d.png',
#  'patches_256_v2/bbb640291ad9d94ba807d63a701725c3.png',
#  'patches_256_v2/891aae056480a951f5b809e2356b4f28.png',
#  'patches_256_v2/5cf1125dfe68b6c64bdef8258cb7521c.png',
#  'patches_256_v2/10e06f99f63eeff66f7d4f7d9cb7ab35.png',
#  'patches_256_v2/64d67bac26dfc1722d0ca777fec84033.png',
#  'patches_256_v2/9135070350106d3ab7095252c3754f5a.png',
#  'patches_256_v2/120e165ec6ec152feeede3be1f7167ed.png',
#  'patches_256_v2/1edfa167c63bc0b12eaf7a65b5fd233f.png',
#  'patches_256_v2/a44b9e78beb7c5363a2ef7603af8f367.png',
#  'patches_256_v2/9065f3700f48859d29d7e5162fa67b79.png',
#  'patches_256_v2/f81a5472f45bc432d05cd1f7c990812d.png',
#  'patches_256_v2/972476d1ad53b7f038c90e91fdb362c2.png',
#  'patches_256_v2/5a3b54dca627288c647ae2e7fce817a6.png',
#  'patches_256_v2/cf8721c41b2e29776c94baa2ce724025.png',
#  'patches_256_v2/87b8670233273d7a6840e864eb6b7e9a.png',
#  'patches_256_v2/e443e0b7b4159f884c747264ac9974a3.png',
#  'patches_256_v2/69141a3192ccde76dd34412601e72df1.png',
#  'patches_256_v2/c163b1dadb01f0238b5a8f2ee03340cb.png',
#  'patches_256_v2/412b5c9eeeb17dc1f53df6f7137c7c49.png',
#  'patches_256_v2/b89f6789391f9f7a19867b2f278f41ce.png',
#  'patches_256_v2/118620a6ddc83fe5deaa137a96b08177.png',
#  'patches_256_v2/5f37d318cecb9cdd5513fe2df538b58e.png',
#  'patches_256_v2/be1850eb78a7ace82ebdb8d77a6e8ec5.png',
#  'patches_256_v2/f8fb617f49ed0521968b54596938416f.png',
#  'patches_256_v2/1a549f7ecc126e46561ac730e556e7a0.png',
#  'patches_256_v2/49385e59a015a7aab64ee40f1adb9904.png',
#  'patches_256_v2/9c2ed3c1534837b62c1c1c5c206c7b22.png',
#  'patches_256_v2/48030aae2032343fd01b562a567c6f29.png',
#  'patches_256_v2/56f877779ce8ef6d74e772962640dc4b.png',
#  'patches_256_v2/b2005781163f6fc7c5479e40a9d8f7be.png',
#  'patches_256_v2/0648f2272d526ff1c0332c295efd1a1a.png',
#  'patches_256_v2/05f376b3965ddf19e6593f294f177f68.png',
#  'patches_256_v2/0a247a5465b2bda21ed9c84a19338a0b.png',
#  'patches_256_v2/d2063a99859422dbb3c95c17af6a6172.png',
#  'patches_256_v2/d2864090b9893f6b2f62482eeb7f2c04.png',
#  'patches_256_v2/1702569de7d9f417ff07e2ddb20d1977.png',
#  'patches_256_v2/446e3a147c711cb6df07c5df52a2b398.png',
#  'patches_256_v2/a9d6d8ad420894b9579192a3e065ea66.png',
#  'patches_256_v2/a80a54723a2c1e710821a9a6745c3ab5.png',
#  'patches_256_v2/72da3c16e694499fad15763e3ff160c7.png',
#  'patches_256_v2/5ea596715e9d9900d3b7a090a102ed02.png',
#  'patches_256_v2/ee467b7a6f970014d93b28f85c6b937e.png',
#  'patches_256_v2/0618c1a19ebbc2c20821076e8f690e7a.png',
#  'patches_256_v2/678d512e96a38bea30cca3db07abb4d2.png',
#  'patches_256_v2/2260a5aed3f4af15c184b632f4f3a772.png',
#  'patches_256_v2/d53cff142085460e0c3d5920bebad578.png',
#  'patches_256_v2/555d471c6c62c7072e8410f640f24f94.png',
#  'patches_256_v2/d0459ccabd7d3c267fdc8a9d89ea52b1.png',
#  'patches_256_v2/e60c09013238fec366d9e6a261bdf7b9.png',
#  'patches_256_v2/d63714146d530027efda4e8d9976cfc4.png',
#  'patches_256_v2/47df74520a42c528a397f3efae5ce557.png',
#  'patches_256_v2/29f6729aa6165d5bd6a76dd486555415.png',
#  'patches_256_v2/e15cb4e7391d36037a851de355db3045.png',
#  'patches_256_v2/d7bab5ddc8f874c1a826e29b0c37beb1.png',
#  'patches_256_v2/630a518528630621ea9ad8a9b17446fb.png',
#  'patches_256_v2/633faa935fd69ffdaf94f74024425014.png',
#  'patches_256_v2/35f66ee8aa00389e090c1307222bd48f.png',
#  'patches_256_v2/cd1af034458336c888e5d13016b076ea.png',
#  'patches_256_v2/8d6b4fd4b51480f0d143a8388634288a.png',
#  'patches_256_v2/feae6d9a117be9c3bb673f7bc2ff3236.png',
#  'patches_256_v2/86590597a17d63ac19a78e02e9f7fa77.png',
#  'patches_256_v2/eb3917894ef350b1c5670fca3a49d1f5.png',
#  'patches_256_v2/9df77e62fdc74824cb3ab34fd436f270.png',
#  'patches_256_v2/487d05883abd177704055a93810d6d7e.png',
#  'patches_256_v2/1314c92b84bdcbf9f431953adba302ac.png',
#  'patches_256_v2/da67020cd56ace7cc1dc43d581ade859.png',
#  'patches_256_v2/1f2a19da88fc72846138db38c9ba0237.png',
#  'patches_256_v2/bfcee3a63601738edc440839f4b6e2a3.png',
#  'patches_256_v2/c70f8d3e04645468e106b6c139d00df7.png',
#  'patches_256_v2/d4d3b9c00e2b5f870f9b5af99b76d1ee.png',
#  'patches_256_v2/f71101984788ef61483a979afb47530b.png',
#  'patches_256_v2/24b987744d793cfa8080f3ce83cb84be.png',
#  'patches_256_v2/a9e6a0983385c6b7514e604419de0cf8.png',
#  'patches_256_v2/12acfc5c3ed232f5490b59ded9e8f1c3.png',
#  'patches_256_v2/d5820b4de443e133bbae045efb16e8b1.png',
#  'patches_256_v2/e8b38f8e485cf7c2191314f62daa84ac.png',
#  'patches_256_v2/de59f6ef799a79adc2a56f2f75e7ecda.png',
#  'patches_256_v2/6d545e2687967852e0b14afc481fe014.png',
#  'patches_256_v2/48932e9b4c78b4b469c598fba4f68981.png',
#  'patches_256_v2/04fc36d04523f392f25317d609e44c16.png',
#  'patches_256_v2/c151407b52689da6549d958334faa741.png',
#  'patches_256_v2/9c271bd12653540232012d05e062e095.png',
#  'patches_256_v2/f58448dec96355a113b78ddf88999d93.png',
#  'patches_256_v2/ceaff078f481bda8a92c06f7a762845c.png',
#  'patches_256_v2/dc83e44f06c043218b97998d4e3d0601.png',
#  'patches_256_v2/2ac50defbd1db8dc395e4a73ad460b49.png',
#  'patches_256_v2/6ee42b752da86b2dbb68367f8899c4eb.png',
#  'patches_256_v2/a39d56da4bda7e98a19f2c6a1ba04145.png',
#  'patches_256_v2/9e81641bf3dd4e86e12530df6886ee77.png',
#  'patches_256_v2/55b728f617b4f62d7fab1518390107ac.png',
#  'patches_256_v2/82606b1a60b8c04368e7a46f739e5940.png',
#  'patches_256_v2/ac5f654999ab7203e1f5e775a52a21d0.png',
#  'patches_256_v2/9a6929888ced3a4c90f04f569f44163c.png',
#  'patches_256_v2/6c62e760600b0404fd0853b6bad3c9f2.png',
#  'patches_256_v2/15a559a1a7b8a0b1b9a97e960dd4b250.png',
#  'patches_256_v2/848c7b50c7b32d6ff7a987a372fb0c10.png',
#  'patches_256_v2/eb7c235245133e9762cfa989a2749f73.png',
#  'patches_256_v2/f61e32476054ed4cf726a6785297fd69.png',
#  'patches_256_v2/a1f79629024bb06bbcafb26a03e726f1.png',
#  'patches_256_v2/dad419bb702ecb777202b28c34973a63.png',
#  'patches_256_v2/1605848bfd603a73e2bdb73189bc19e9.png',
#  'patches_256_v2/51af9474c4cd7b1a80f5383a36fdf8c2.png',
#  'patches_256_v2/38fadb20752c41aacf99fbd9d917beb1.png',
#  'patches_256_v2/ffbf0849c345331974054a93ef5149f7.png',
#  'patches_256_v2/ca58cb05cff28b20d125bfecb014e947.png',
#  'patches_256_v2/722e5b11b9d951072adefc1335513d4f.png',
#  'patches_256_v2/abd7d1471420d75a4d7798d3bcf67e53.png',
#  'patches_256_v2/d0d58c0338ea95d06d0d3e7e6f02cb0f.png',
#  'patches_256_v2/54b2eb5c327b3e7547502ebea115592b.png',
#  'patches_256_v2/eaed288d37dbf28c2993b6526d9ae3dd.png',
#  'patches_256_v2/f3f997153352bebc5ce62db0fe30ab4b.png',
#  'patches_256_v2/5d2843b427257ec7456c61a74ba74137.png',
#  'patches_256_v2/d4e5b669944954a3a620d5ad6cf22fe1.png',
#  'patches_256_v2/05bf25921d98825c239c53547a3c5f70.png',
#  'patches_256_v2/d010731b78f3e40faebfc21abd0f17a2.png',
#  'patches_256_v2/8d517bfb05c968eff80fea140e433743.png',
#  'patches_256_v2/8e63a7755ad5943a5492c22ddca98fe6.png',
#  'patches_256_v2/d56e762edbd48d98499e1d80d55f7325.png',
#  'patches_256_v2/96cc41e860a372dcaf06c91fc6c29154.png',
#  'patches_256_v2/fd75a2377ce0a6cb0f0cf05fcb1c3e93.png',
#  'patches_256_v2/fafc4fb49c546b2a2f70342c104cff30.png',
#  'patches_256_v2/16e176191d02be3d4da97b30c16b0c5d.png',
#  'patches_256_v2/9ad21ef7272930d9a23254398dd8a4bc.png',
#  'patches_256_v2/5483fdbb2c95a1811fd7b7ef3bc62172.png',
#  'patches_256_v2/7ac4a0dcda505b2fd6529efe7b7b1659.png',
#  'patches_256_v2/a4d5db08fdb2e8b2a7dc82d285e47d4a.png',
#  'patches_256_v2/5ba641ca40f393b5a637b3caa503f1ac.png',
#  'patches_256_v2/9955212dcfbc4e433d3c7ae7c5714323.png',
#  'patches_256_v2/7f91fb73a2a5cfd4a69fac11cdbea647.png',
#  'patches_256_v2/96b7148dd1530a2a57c186438ec7fc00.png',
#  'patches_256_v2/ab5288880a9665770e784d6c73259ece.png',
#  'patches_256_v2/7e7b59b5a91ee5034cf3cc8d38da2bb0.png',
#  'patches_256_v2/30bdc896af1e4704e379bcb39764cdeb.png',
#  'patches_256_v2/44e484252518aacba8fee4b429f02c88.png',
#  'patches_256_v2/5a0b94041bf59249c1ee1bd07aefab6b.png',
#  'patches_256_v2/79972fdeaa535cadf36985ce701b67d1.png',
#  'patches_256_v2/0229f34672a769686c5b7eaf67affd45.png',
#  'patches_256_v2/5949f8b836fd24f5f267a664e6b75eb7.png',
#  'patches_256_v2/ed6d5fa4f3b41543946e09a491acbaed.png',
#  'patches_256_v2/6ebc58688dc553af552e21c1973eddcd.png',
#  'patches_256_v2/e3a0f3a22cdfdb603590765e5f627b3e.png',
#  'patches_256_v2/0483cfacb3ee92a4d36f2ce1173c882f.png',
#  'patches_256_v2/ba6bf3311d2a31119a7f24cab129ef3c.png',
#  'patches_256_v2/d75cb6b54bc34f08bf26c6a9d854787a.png',
#  'patches_256_v2/01d345fc1b207a4dd2ffcc58a0360530.png',
#  'patches_256_v2/826316bd08bf7e51cd8860366c4080ff.png',
#  'patches_256_v2/80fc04e5067323ba1512c366c6fb2495.png',
#  'patches_256_v2/985d752ca7cc95d1303bf15cd0049037.png',
#  'patches_256_v2/1a69bff107f9acdb988ad4c46492514b.png',
#  'patches_256_v2/7e0b8e06553167d251b47d449a4a0026.png',
#  'patches_256_v2/4f12510c9adaf3259303ca25c9f2d13d.png',
#  'patches_256_v2/aee3c2b3ca1f4bd5d23d5e52efc17c0f.png',
#  'patches_256_v2/1923efa8a656f97129951e9166bd33d3.png',
#  'patches_256_v2/f99c95a058c97fe51953fdc81a6d0e64.png',
#  'patches_256_v2/fb9299f8c31ebcf1d33281547e4590be.png',
#  'patches_256_v2/be4f8d4a841dd6edee0a946a01b7633d.png',
#  'patches_256_v2/a6b743d9bf6b9c20b91d7b93c9e6d500.png',
#  'patches_256_v2/303e1b01d14f253334aca10b69888fe1.png',
#  'patches_256_v2/cf5c591e4e2036eda621016cb4a944fa.png',
#  'patches_256_v2/1dd25a492a62a46a40686100109e0d4c.png',
#  'patches_256_v2/7529c82cc745db52558cf67e17beab04.png',
#  'patches_256_v2/cab1cbe74fa4d19fd3190686500e1ad7.png',
#  'patches_256_v2/9778ba6897ee18e03b1f7df1c67db2cf.png',
#  'patches_256_v2/aa43c53e2dc2efaa65e43c2417f91bb9.png',
#  'patches_256_v2/f14c0e580097ceb11af4e0ad183397d5.png',
#  'patches_256_v2/8a44514ab02d9a1d10cde88cb66d1b39.png',
#  'patches_256_v2/5bc1d2a4fbedfe945272b5d87ab0785f.png',
#  'patches_256_v2/19f03be9318e268d6feb507ec41799ea.png',
#  'patches_256_v2/b163e020ef675b703d18bf04874ed329.png',
#  'patches_256_v2/0a1f861067cec70b82e1b9a15661b498.png',
#  'patches_256_v2/631cf0837f43760ecb9e970fc6748d53.png',
#  'patches_256_v2/03bd4f4175d7ad027098921bc9206ffa.png',
#  'patches_256_v2/36214e0dfb3034fef09e7931af301545.png',
#  'patches_256_v2/ea8e75c1b1157a4d3aeadd7468eae73e.png',
#  'patches_256_v2/ac74674d4dcc51279e66cbff538f48bf.png',
#  'patches_256_v2/65af34e1eeee2a60aff7bd450b139946.png',
#  'patches_256_v2/f7ec668832aa20c3c23541810b4f7f73.png',
#  'patches_256_v2/b9416c00712a8ab28638b73291143616.png',
#  'patches_256_v2/0a5c0cd9ed9a86368ee9d4268ca648f0.png',
#  'patches_256_v2/a860f44f8a7bf0cb1d3cb92a1c7db5ab.png',
#  'patches_256_v2/ad1efa396a394f7924f5f909e5281bc0.png',
#  'patches_256_v2/58eada0734a50067f1fef37ef33918f2.png',
#  'patches_256_v2/dea5d7f661baedbc30f0edae2a521e8d.png',
#  'patches_256_v2/b309ebf8befb964a47fb3881d3b78526.png',
#  'patches_256_v2/ee4ad689cad495d0dd0ca135ac61df9f.png',
#  'patches_256_v2/d2e9dabd356d2b60837550297815972a.png',
#  'patches_256_v2/40b7899124240f68d3f0f4c3c2e6d21b.png',
#  'patches_256_v2/b18943e4898e2a8d0444319c7c8352ae.png',
#  'patches_256_v2/632069e1c8a5c17e543840fff22b109b.png',
#  'patches_256_v2/39cd93504e79fd1998474ec0a3be4bf8.png',
#  'patches_256_v2/9f582421f3c387e7b5b92a0962c83165.png',
#  'patches_256_v2/10c44afb983a7edd53c435cde3ce5753.png',
#  'patches_256_v2/2369028dbda7ca85e60e566b4fde5093.png',
#  'patches_256_v2/591ccbd7a27d16976a12d3f8d8d4a51c.png',
#  'patches_256_v2/e60339eb010a5f8aaea7cb9f93125276.png',
#  'patches_256_v2/9dfca250e82aae5888e05cb77c109c51.png',
#  'patches_256_v2/2d0b0bcccdde6aaaa376913d063fbf8a.png',
#  'patches_256_v2/306986b20a139bc4a4b1e794800e6b31.png',
#  'patches_256_v2/07300671f5097493c3df9b32b3f5d115.png',
#  'patches_256_v2/429768c6bbb397a3029ee36b9edf52a1.png',
#  'patches_256_v2/bfc3aa5e423337dd75792430b85a0f42.png',
#  'patches_256_v2/c279b01a213f22ab2e68fc6a2dd78494.png',
#  'patches_256_v2/55b2b30e933f4a3d02d812fa988eaca4.png',
#  'patches_256_v2/e31f5155ad85f52fe86e712a1f80cb3c.png',
#  'patches_256_v2/2bd791b805e1efc09a10ea869738d72d.png',
#  'patches_256_v2/758ef1f63bb79dbd88bb29ade4793eb2.png',
#  'patches_256_v2/4e6554e28d6a6931b066e2cd76dd212d.png',
#  'patches_256_v2/07c56a5944e888b0f46097f79e9687d3.png',
#  'patches_256_v2/aa672e9b76a402f3c2095ed04715de69.png',
#  'patches_256_v2/0c18fc047270b780466aa45c54b3f97a.png',
#  'patches_256_v2/6838ee5edb1f663b76b6bcf5376a5d2b.png',
#  'patches_256_v2/f310f4150880c7690e02ac3b09ca078a.png',
#  'patches_256_v2/ebd59243aa50927f5e5a26fd5b55ae82.png',
#  'patches_256_v2/0603f124cd063c62c264f5849aa902d2.png',
#  'patches_256_v2/3466e74b57cef92820d7d53408717138.png',
#  'patches_256_v2/81422578600eb3dc1b1c45285a6a7fda.png',
#  'patches_256_v2/0172d43089e15ab5d0f784a316c672b5.png',
#  'patches_256_v2/d24dfe6120b749debc7c8298e210ff33.png',
#  'patches_256_v2/3c53883b601bf8d30f2837a8ff628f96.png',
#  'patches_256_v2/d91b3a65474d87ea0961a92d493ff10e.png',
#  'patches_256_v2/e7c541db02b54a329b3caabdf8a00c95.png',
#  'patches_256_v2/2235f7da2dfa68a3d2f7659ed361451f.png',
#  'patches_256_v2/64e98dfd178482a96c88663ccaef0af5.png',
#  'patches_256_v2/fe7e7bf3c3a3eecf8dcce4e0a58ca36e.png',
#  'patches_256_v2/dcce5b5b30df6e6f1618b60d05799507.png',
#  'patches_256_v2/dbb88b7d6b5252c5b8c6e5945ced5b90.png',
#  'patches_256_v2/6fa23bb9def54a782d196813ef63c612.png',
#  'patches_256_v2/c9a5f501db779da371831d4a7a013a8d.png',
#  'patches_256_v2/1c9ce294b70cdf02d10789e86051bff5.png',
#  'patches_256_v2/d3b0f026eb2b948198ad7c7a88c3c69b.png',
#  'patches_256_v2/136c28dd6deff5e4cd92747f34cf7878.png',
#  'patches_256_v2/81632d96431b6d8cf14c623a68ab5208.png',
#  'patches_256_v2/56eb5ecb573cadfe2f4471664be550e9.png',
#  'patches_256_v2/12a83daea514cc49b6b452bb0fcc6a3a.png',
#  'patches_256_v2/7d64b582091e8c030e16d6526f04bba3.png',
#  'patches_256_v2/583a546787c5ae9480cceef4f3ecb5af.png',
#  'patches_256_v2/881a1ebd859bd728b248e672e94aaa2b.png',
#  'patches_256_v2/5ddda65c91e8e5ad982f46218e46d464.png',
#  'patches_256_v2/5ef707c51a7a8bffae91b0def4fe5077.png',
#  'patches_256_v2/0e42ab2cbd3097e6160778e4a0b30214.png',
#  'patches_256_v2/f167a8b0d4a1636d674670cdb6437f2c.png',
#  'patches_256_v2/77bce806abb36a16166ec8b0dce8a8f4.png',
#  'patches_256_v2/51a7498bbaca8f1ac8cd0aaa069c21c4.png',
#  'patches_256_v2/33ad1c3c83419e9ea191c3d1ec6aee11.png',
#  'patches_256_v2/d7eedeac775f3ee9eed526f71b873b41.png',
#  'patches_256_v2/c5b66aa69cc67432bbd416075b9acb3b.png',
#  'patches_256_v2/5f5fa0f2a8fbe8ef92ecb79e4fb80966.png',
#  'patches_256_v2/7b38ff3202b556a14da7c7966aceeab7.png',
#  'patches_256_v2/a52fcd44fb0e0362b5856f0ffe919e8c.png',
#  'patches_256_v2/ebcb7b6ea12fce47b4709bce6baba7ac.png',
#  'patches_256_v2/be055df621c49a0b41490224b2271094.png',
#  'patches_256_v2/3abc90b889f6d0c3444a27791cd9441e.png',
#  'patches_256_v2/563d6b39e4e1440508ce1e0b9e7a1555.png',
#  'patches_256_v2/3391a75e7218bfc53548c766e574dc7b.png',
#  'patches_256_v2/0f5329af50821c4d3d7bcdb5a3724236.png',
#  'patches_256_v2/722a2e7dd2a88232977387dc74d613d5.png',
#  'patches_256_v2/ea2e8bc52d8cbfd6f978246162a35440.png',
#  'patches_256_v2/049eca40e4488de2633fc12ece1daba5.png',
#  'patches_256_v2/97f9612413a3134d7cf71d2ba67c21e9.png',
#  'patches_256_v2/b6a514a86fbc72b91353ed38b659beea.png',
#  'patches_256_v2/5909edb92842a0e18a2e94ef843b8440.png',
#  'patches_256_v2/d17d91fde688a6e70e5fa2a97b663e2c.png',
#  'patches_256_v2/a21cbfae20617bb1a89e926dfc7c1b39.png',
#  'patches_256_v2/3d205c350d7224289d2818e94d4e0c79.png',
#  'patches_256_v2/6d2c1fc8f048c4a5709b988db945f739.png',
#  'patches_256_v2/b25b2a7074c99dd47d6a7b747b2e3aa9.png',
#  'patches_256_v2/85c33836ba59473695756be88ea2f7da.png',
#  'patches_256_v2/0c5a6a4a95c01a2e656db4adc8c6e731.png',
#  'patches_256_v2/a2b22825fafedba8006dd07f708d0510.png',
#  'patches_256_v2/e922696cca73d2a6075bcdfe56471a5f.png',
#  'patches_256_v2/147c08d9ae0e1f833805d8e8c5aa85cc.png',
#  'patches_256_v2/8f2f1e14a4676cf032975bb76c889942.png',
#  'patches_256_v2/f09f8991a8bbec61d9670ea150e1efc4.png',
#  'patches_256_v2/f939663d2739eba797e3642a770ab7c5.png',
#  'patches_256_v2/0f9b7567315a58665866f53b8dcd890e.png',
#  'patches_256_v2/f985107dec615ff501cf059e630b6f88.png',
#  'patches_256_v2/e98919b4efa41cf5c4adf0b05845de80.png',
#  'patches_256_v2/8427cd69df8bd64b1b63dd0ef5f83f84.png',
#  'patches_256_v2/d1ff571986e664ce981c158bfd6934d8.png',
#  'patches_256_v2/01c96d77320405f2f077c3b7065f30d0.png',
#  'patches_256_v2/336cbfc1f8110f84997b51f8cb692c2e.png',
#  'patches_256_v2/9a7561ae689aadc6693a1ed53e5f3f7c.png',
#  'patches_256_v2/a3e27c859a2c95294197bf819dbd09a7.png',
#  'patches_256_v2/cd84990f26e7fc867d9bd907baedca8a.png',
#  'patches_256_v2/34153a9297ef749906b1dd000915c19a.png',
#  'patches_256_v2/9ebd86f00f8edc89928ec41c6d933ba5.png',
#  'patches_256_v2/39012e0f56494917313ea0e31fc8a94d.png',
#  'patches_256_v2/0afe073526ff7576fdc4adc57b2ce857.png',
#  'patches_256_v2/2005e2c817b90afa1e2aa34f8d6f631f.png',
#  'patches_256_v2/6725c75bca74a9d776d2c3cea963e721.png',
#  'patches_256_v2/d2274d308451a465ebbb1f1a94a4d547.png',
#  'patches_256_v2/5694a40c341a594ff2bc5b7f3d6e905a.png',
#  'patches_256_v2/451e2a83d86d0b57f434fbff5d6c4d11.png',
#  'patches_256_v2/741153e174a119deec4237765311e80c.png',
#  'patches_256_v2/d985e34c6d0568fb8eef5ba424897eeb.png',
#  'patches_256_v2/5faf7efd2648439b4b93f13f6564cbfc.png',
#  'patches_256_v2/dfe8c11782c88194d95f092d6d1c9df4.png',
#  'patches_256_v2/3e8a6531f91403cb277cb900b6711b48.png',
#  'patches_256_v2/bcf031819d8e83adf8280a69be5b8d8b.png',
#  'patches_256_v2/dda014ef1328ca98fb34740d21adf657.png',
#  'patches_256_v2/0838b2c8fd91f91e98239c1aa36b7890.png',
#  'patches_256_v2/c4871bc352ec944a9bf3fc17aff6d33c.png',
#  'patches_256_v2/f6212840db061c904b8a93f7a8fb920b.png',
#  'patches_256_v2/23ac1862f3bffddc53004bbff67bb0c8.png',
#  'patches_256_v2/bd77778b738923977013df65fc517f2e.png',
#  'patches_256_v2/e661f442c87f453174a5cc4a5af08074.png',
#  'patches_256_v2/fc080e612b7d61607a3f9a216c388252.png',
#  'patches_256_v2/0374ffc799e6bf3e1deb965c15f68d51.png',
#  'patches_256_v2/a06522f9379ee662a83295ccf406876e.png',
#  'patches_256_v2/75caac3d1e725ce8be4bf6637b04e116.png',
#  'patches_256_v2/40a3e31fa90b57769a8efdefa006e06a.png',
#  'patches_256_v2/84acf03d41ec3d527719b5b87721187a.png',
#  'patches_256_v2/c36f431cee0227048bf81227684af7ab.png',
#  'patches_256_v2/fc25aff3ef720bc242de1fd419b91643.png',
#  'patches_256_v2/99ba11a9b6cd075fa513cf15ebb48647.png',
#  'patches_256_v2/85b20975f5e5b8097cc09510772a0434.png',
#  'patches_256_v2/5e69dcbe00d83fbf1a040e46e50ace93.png',
#  'patches_256_v2/ca4ca4af6460e736443dc86ff904bc31.png',
#  'patches_256_v2/916332e136d23ce6711a9994364476cf.png',
#  'patches_256_v2/dc6db3429ea505d02d165c2508a4d388.png',
#  'patches_256_v2/0514617c6c1e3b7a9c8b9316b4a93b86.png',
#  'patches_256_v2/0232688bd73b1324c67bf7370dc68764.png',
#  'patches_256_v2/f00a2568776e376d3d16bc88e6eb7109.png',
#  'patches_256_v2/82a74a5c69332a1599d3188972c06b5b.png',
#  'patches_256_v2/62b6d702f51c43b14a56459f922c8c28.png',
#  'patches_256_v2/9a2288459b629fa1e10bcf63ce0ddfb5.png',
#  'patches_256_v2/7a41438424ab0006665fd2a7cf557c26.png',
#  'patches_256_v2/40639e34b0fbe7f242edb338c34d28cf.png',
#  'patches_256_v2/1ba813564d5f0a7cd65584d806c880f0.png',
#  'patches_256_v2/9147cb46dd3212c4da554751b3204fbc.png',
#  'patches_256_v2/3216fd3f06460eb5870b6abed0bcb702.png',
#  'patches_256_v2/0f6e45975dba6157936855d194ad313f.png',
#  'patches_256_v2/59de13ff243e7d7589cf5b380e6a4b04.png',
#  'patches_256_v2/b65f69287a753d36e9efdf372e50af8a.png',
#  'patches_256_v2/bcdf50d11d34aa686dfbccd1fbba57e4.png',
#  'patches_256_v2/e417324e2459e6c7dd1aa2a3d1786e3b.png',
#  'patches_256_v2/32b77645d0cacba983211b4a283ee56b.png',
#  'patches_256_v2/12dd15709809aafa0d3ac57dfe831f89.png',
#  'patches_256_v2/21e35b8d9196c712e325b012afffe03e.png',
#  'patches_256_v2/3aa8ac9884e339f74bda5f9252baed34.png',
#  'patches_256_v2/4c6046958333351cf7db9c25974de228.png',
#  'patches_256_v2/46a7ccd90ec4772d25a232877b3fbd00.png',
#  'patches_256_v2/282f7373ac6b21f6b7ac5f46bf5294e5.png',
#  'patches_256_v2/9606d6e71982cd8b00e30814d531bdce.png',
#  'patches_256_v2/882673c97e13758e25020ce3d88bb5a9.png',
#  'patches_256_v2/f9829d20059a7aa8212a1637f010b8f8.png',
#  'patches_256_v2/2d08e68eb97cd2cd1550c91f1e288402.png',
#  'patches_256_v2/ec1c2d465e649543d89393daff66683e.png',
#  'patches_256_v2/5174fadb1486e26f10bd33a434ed251f.png',
#  'patches_256_v2/1fb1a247a9a09de60d73a2ed81882b8a.png',
#  'patches_256_v2/7f90deede36d73e760cc947f583be4cd.png',
#  'patches_256_v2/a68be04aa54ba85c317ee1d003b66b16.png',
#  'patches_256_v2/a004cf4f922c12162cf6de8272809934.png',
#  'patches_256_v2/44f5eef00b1536e38aaca25098317a8c.png',
#  'patches_256_v2/c5520398024fa40261bd3ec2928ef8e3.png',
#  'patches_256_v2/5b825a370cd769ab0a5b97401ecfa35f.png',
#  'patches_256_v2/25b3157cd732bb928cca298451713cb5.png',
#  'patches_256_v2/002ac9e9c6de81351486ec4af9849750.png',
#  'patches_256_v2/b83064393d385a6f076a88330e5b21f1.png',
#  'patches_256_v2/ad21c6d31409c9ccce49a3405e75fd8b.png',
#  'patches_256_v2/c3dfab3a2f86c490d1fb84ffcaefe098.png',
#  'patches_256_v2/da6faf3b7f57890f95a4932984dc1aee.png',
#  'patches_256_v2/4dc894dc3849f79145a9c3abb45c5fcc.png',
#  'patches_256_v2/0068b2912d42ef470374831b5b927ca0.png',
#  'patches_256_v2/3295231caf4462452ba2e4634289f208.png',
#  'patches_256_v2/3e13ba29c8aa1c3f725961a7221c46d0.png',
#  'patches_256_v2/fca6ea708e2fbaf805c191d8b767078b.png',
#  'patches_256_v2/844b35830de880b2d185d8be458dcfd3.png',
#  'patches_256_v2/68f3261a01e4509a0e06db859e12eabb.png',
#  'patches_256_v2/c2d9695f35922520b9a26a971b0ca4b8.png',
#  'patches_256_v2/f0e9d4961bb75db14d03e5c5dfd1db36.png',
#  'patches_256_v2/3d210a3ae3b7120cc4be5b23667d8a37.png',
#  'patches_256_v2/655681d38347d5b3f5ddb80a75c10618.png',
#  'patches_256_v2/416dddf4279785a431bf65f87bbb29ac.png',
#  'patches_256_v2/f3195f1602258c1eb3192865378f5530.png',
#  'patches_256_v2/04b2091370a755fd94450b2e78e1b0ad.png',
#  'patches_256_v2/cefa4749565881f6019a44f45673d76e.png',
#  'patches_256_v2/18c054c36dca06ebad2b15c9762146f3.png',
#  'patches_256_v2/1bee876c75483f50e49261f78bcce60d.png',
#  'patches_256_v2/b55939d8e00de73df77bdb1f5e589d7f.png',
#  'patches_256_v2/9583251774df616a7d3b767faec9d666.png',
#  'patches_256_v2/209972480e3276b5851209dd1a82ca1f.png',
#  'patches_256_v2/a9b0327b1d7aa37c73512e2b5ac26021.png',
#  'patches_256_v2/728cc045875fccb8a31dac7592b88d63.png',
#  'patches_256_v2/30c341a5733cdf9cab5956eb2bf071c1.png',
#  'patches_256_v2/9305946edf65e3ba71fb1c5c99329bf4.png',
#  'patches_256_v2/9818ae40aa1a5265cb7ec182e968f91e.png',
#  'patches_256_v2/c6d68a0d34b074150662075c2566e8e0.png',
#  'patches_256_v2/cf0e3a289f2af5ee980c8a7cf5f56576.png',
#  'patches_256_v2/264bf8c83c9b80561f3d8a553befcf3b.png',
#  'patches_256_v2/10e39533de3d4187c9c9ed39a86bf571.png',
#  'patches_256_v2/7773aab0c3082353860f78bde22edc5a.png',
#  'patches_256_v2/c86a8d128f646f3b69e998f2a6d4bb50.png',
#  'patches_256_v2/c5c8c1698e8ced227dba3f97b76c0cb1.png',
#  'patches_256_v2/6157197c170cbdd8f63177b238e2e2af.png',
#  'patches_256_v2/3a714d5e3cfdd76a7c1af690974293e7.png',
#  'patches_256_v2/09a9efe7b4b08fd022cee7c2aaae9182.png',
#  'patches_256_v2/6f46b90a09c3ac06938a4b29dbc83673.png',
#  'patches_256_v2/1731ea8e4bf9dc512ca5c4ccc7646365.png',
#  'patches_256_v2/7ad71e6902bf46a2e5083e515ac23119.png',
#  'patches_256_v2/865f791b7bdccd86a9dfbd5fa62ffd4a.png',
#  'patches_256_v2/8a21699d40348561683ad31c895d6e53.png',
#  'patches_256_v2/9b6ba427a21e7f2343e5bdbf84f4115d.png',
#  'patches_256_v2/afb9839dd837517cb1d4c91f4dd8139b.png',
#  'patches_256_v2/f34e773e9e6bc10ac4b98352c8f87601.png',
#  'patches_256_v2/7daeb8b69d26e37286030e33b4765aeb.png',
#  'patches_256_v2/050500e56bf881ae3485dba08e9fe00a.png',
#  'patches_256_v2/c1b8503cd415c6be0f8a9e1d999578bf.png',
#  'patches_256_v2/5cfef076a85da1fcac7b30ce4030e06b.png',
#  'patches_256_v2/f1b7f30b1ef2451bff060eb2c2cfbe09.png',
#  'patches_256_v2/414fc81854e30410e53f887b11716d03.png',
#  'patches_256_v2/b387d3632b1dfd303be830d42243cab5.png',
#  'patches_256_v2/f5f375dcd3e303e9bb651eec0aed1deb.png',
#  'patches_256_v2/ba487b578a9f33ab0adafdabc1eeffd3.png',
#  'patches_256_v2/b10b95897a97b1a8f8b0a90c6d51fc24.png',
#  'patches_256_v2/8b64908ce1f315a7bd3d845bed02e220.png',
#  'patches_256_v2/a0f22ae208dc7c33fd7a529c06d62ada.png',
#  'patches_256_v2/7ac3a6dc7e53bc630365e820651163bb.png',
#  'patches_256_v2/cc9e3f29ae160d94cfaf9e81770cebf4.png',
#  'patches_256_v2/2ee7e2c7ca3133bf9d8c3ea5b2f69c9c.png',
#  'patches_256_v2/d2deaf6e59db98dd265037604aee1fb7.png',
#  'patches_256_v2/8e41b69d1387e38251c129170a58c338.png',
#  'patches_256_v2/fe0167f2bc09c8250578b896a2e6904c.png',
#  'patches_256_v2/c48bd155b7638ce473ae514f56285328.png',
#  'patches_256_v2/c7342fa4c5d1c6a69a6b32f499b97e23.png',
#  'patches_256_v2/4383f3e0ecc8db8e5749f14edb2352af.png',
#  'patches_256_v2/0e518bc10a840703c2233542ea3632a6.png',
#  'patches_256_v2/71ba02b09b6d65a56e86aea9dee9fa14.png',
#  'patches_256_v2/95a3dad19539b5ca8b0d45a366d0126b.png',
#  'patches_256_v2/085839294823a207f57bc390f7dc5097.png',
#  'patches_256_v2/4aff63ccdc3da6563a337e060e8d7a30.png',
#  'patches_256_v2/58ab7dc0919eb7e93cafd64b01de1086.png',
#  'patches_256_v2/c9e9d8e88bd5e92dc9d00f63b3004672.png',
#  'patches_256_v2/559fcd4ffc3df4655987f6c27848da5c.png',
#  'patches_256_v2/c5e95a98882723d15ecf28b654789aac.png',
#  'patches_256_v2/2e210c78f3d287d045a046c425099ca9.png',
#  'patches_256_v2/7a81d063384ec569b3496f3b9347fc6a.png',
#  'patches_256_v2/49342ded0f1e63a8fe905095577d4616.png',
#  'patches_256_v2/245716314e3d11db37eea2c294f8b805.png',
#  'patches_256_v2/2c16ccdbe11fafec0363e2393d06929f.png',
#  'patches_256_v2/5ce092784407829456a4fa016f5311fa.png',
#  'patches_256_v2/3be4b2081f6f51d780ffc466c22836dc.png',
#  'patches_256_v2/2c7407bb12fb95451e5cdc0b8aec3a84.png',
#  'patches_256_v2/e33379400092aac392946d5c341126cc.png',
#  'patches_256_v2/e1a929027777540ba3b33bf2896891ff.png',
#  'patches_256_v2/a8ef3a25c4d528093ad3bd48a94456ff.png',
#  'patches_256_v2/c2993083f9f848ff044351b8995c5875.png',
#  'patches_256_v2/109b9d2e9a42e06ee4ab8e797ac879c5.png',
#  'patches_256_v2/c02a149a01559b176b7e1c95cb4d8d8c.png',
#  'patches_256_v2/bf71029b1ac6614bfec539797fb55aba.png',
#  'patches_256_v2/9a69135101a6e8e65cd2cebb4399cfff.png',
#  'patches_256_v2/601261263c7e043763575f0a802b567f.png',
#  'patches_256_v2/d44b64073333861ce3daf8ef65070b59.png',
#  'patches_256_v2/c076b6ba7f2e163d8e75eca43a28589b.png',
#  'patches_256_v2/989c7a89416b54a5a5736d5d7bec4ac8.png',
#  'patches_256_v2/46e7456ff76f19aedd40b294cb3f9da9.png',
#  'patches_256_v2/3cf5a3fe433c45a691d6b0158fc2147c.png',
#  'patches_256_v2/2a1b86176a07563252eff13a2cdad730.png',
#  'patches_256_v2/dd577614bd1b385406aedb3679cb6a75.png',
#  'patches_256_v2/b192eaa29353018c3fee9c9cdb4ab19f.png',
#  'patches_256_v2/2e976cd39971f68d444f4f9cdfb73cce.png',
#  'patches_256_v2/b65596c756008bd2452219f46b5ca9e8.png',
#  'patches_256_v2/d8b6ffc3757d380879b10d3ae332375d.png',
#  'patches_256_v2/89f32e3a8adc87f63592e2dfbbbabef0.png',
#  'patches_256_v2/1a8685d6dfe2f7880df1ce1387914e37.png',
#  'patches_256_v2/2dd82c5bd2c49b6e34d77c359bf79f56.png',
#  'patches_256_v2/ac8d06421f177801ce3b406093eade2c.png',
#  'patches_256_v2/a6e69bfb468f656be527e6ec748ec8b1.png',
#  'patches_256_v2/d09aece7add8489adb8924249f1b2aff.png',
#  'patches_256_v2/2b1987f8820e4039c73493b60fd78fcb.png',
#  'patches_256_v2/a6019603632dfefafc20df8bcacc6292.png',
#  'patches_256_v2/ff5135050353c92215abf73387a845d9.png',
#  'patches_256_v2/e65eaa93404e5c719d80f13fbee77696.png',
#  'patches_256_v2/e57bbcfc73436d10299d951f1a7b617f.png',
#  'patches_256_v2/a4515317846ee435f776738068fc3403.png',
#  'patches_256_v2/a0ad55a72e3eb508478180d54cd62b22.png',
#  'patches_256_v2/ea2b220fd9902b84bd5fd78c4216b878.png',
#  'patches_256_v2/04b94d084f177a64859be6a11cdbf481.png',
#  'patches_256_v2/c7c20966f6e2c36e0b1efd2915c66b9d.png',
#  'patches_256_v2/1736f46623b6a08d19320374df33a858.png',
#  'patches_256_v2/23b188ba498b37193f0787c34f27e1b5.png',
#  'patches_256_v2/faa90088d4a6ce437a657bf305d0af77.png',
#  'patches_256_v2/499a0cb1e7dbab1246d3f1d92f514f25.png',
#  'patches_256_v2/273419f7727eecb5003e447846bd538e.png',
#  'patches_256_v2/6b245d809572e59dc47870bad31c6948.png',
#  'patches_256_v2/20eebc425a7e6505c7d5301b1da64f6e.png',
#  'patches_256_v2/53eb862f016531a600e51ed461ad64a9.png',
#  'patches_256_v2/7f716ee034f10fb5bef51d9be0185c45.png',
#  'patches_256_v2/6e8e5137819de2f9809d18f8a1b4af0d.png',
#  'patches_256_v2/c41ad28576e1507ca315d0e6541c2b4f.png',
#  'patches_256_v2/31bfb7562d1076a334326c11d690cacc.png',
#  'patches_256_v2/7a4c9678ce121bf667a5db448e56981c.png',
#  'patches_256_v2/e8978d9f0afb9637f2cee24bc0f810c1.png',
#  'patches_256_v2/b820492574b054b69df59f63235addf5.png',
#  'patches_256_v2/209e11e294a5d9929222c636aa6487fd.png',
#  'patches_256_v2/4c063dfc81e529ca82983b00c2fb7367.png',
#  'patches_256_v2/406711938b584d70b9b7ab802b8b9415.png',
#  'patches_256_v2/e03f2a056367ff174c18e585907aed5e.png',
#  'patches_256_v2/3b04e1c58da0874a2569b4aac7e4847d.png',
#  'patches_256_v2/3f8f35961a056c23b9c0f71c87a2ea13.png',
#  'patches_256_v2/341f5b25be6c2e37f5fe0163abe78b63.png',
#  'patches_256_v2/8f820cc363699ce36ecee8a2acbd0985.png',
#  'patches_256_v2/d8eb750e2f41e3481a8adef3cceb10b3.png',
#  'patches_256_v2/4a134718fe0652b836988fbb019db68d.png',
#  'patches_256_v2/a7ef519a902e7321490cb2fae9d93d37.png',
#  'patches_256_v2/bab2d9671a39fa5934f4fbceeba72546.png',
#  'patches_256_v2/13b7c86ad2f109050ef29864b4b9a448.png',
#  'patches_256_v2/14d5d3ad926dd2ccac25e8865336c770.png',
#  'patches_256_v2/9ca773d96604b564aca1618c0118ea33.png',
#  'patches_256_v2/8e5c233e6d84bb2df7813e3796ee364c.png',
#  'patches_256_v2/a3a690c6c35641af2fdd5c19f32ac7ea.png',
#  'patches_256_v2/c5bd732f7e89096ec39f88f869005cb7.png',
#  'patches_256_v2/7bdb25659f06750afe0832136a7c7720.png',
#  'patches_256_v2/bd1a7f177ddabf36b0cc71e9c2db18d6.png',
#  'patches_256_v2/fe6b5ae7602faf4cef5ace9854882b6f.png',
#  'patches_256_v2/b1e4460563e7b6705c06b76fa3e29d9e.png',
#  'patches_256_v2/0648396adf7c8cd021a6b245ea2be119.png',
#  'patches_256_v2/1398c41d9ec1650ad487705136377c39.png',
#  'patches_256_v2/2287a504b1fe4b0fdc9c6d52a43bb712.png',
#  'patches_256_v2/c1b8d3f49320e5893bb2622043180647.png',
#  'patches_256_v2/0ea1bfb49155534d7331c288e3573dcb.png',
#  'patches_256_v2/cd765a1d10be468d8038b70c3cc69d3c.png',
#  'patches_256_v2/cc7d8f5eb55fe052ce9bd127ef4a12e8.png',
#  'patches_256_v2/6bc819fa7f6b3b95e28ed8917167a5c6.png',
#  'patches_256_v2/c00aeb648ed5cc4ae5e1153b3c146ea5.png',
#  'patches_256_v2/f1030fa6699dac65a581b992c0c0c843.png',
#  'patches_256_v2/880ad4321e13ecfc7977f153b601aa2b.png',
#  'patches_256_v2/9bcc71f31c28b72008d23118265d3b76.png',
#  'patches_256_v2/81d47d4e8a422f4aee066fbfea61192d.png',
#  'patches_256_v2/8c226ef109976d1d3fc08a87889cf1c7.png',
#  'patches_256_v2/4055d19ae466bdfb407eb72b167054cd.png',
#  'patches_256_v2/1d660c64ec952b957744637ff743b1fd.png',
#  'patches_256_v2/34913b81dd3a94c0fdabf917c35ed6d2.png',
#  'patches_256_v2/7bdb79036232895706efa5536744c0d5.png',
#  'patches_256_v2/999bdb51cf52422314b18044f0370839.png',
#  'patches_256_v2/924cbabfb7d27e74fce2953a0188181c.png',
#  'patches_256_v2/073264a55ce8c13cef19c5ec4b58b89a.png',
#  'patches_256_v2/c171eb1e74fd3e67e3715966030d5e9c.png',
#  'patches_256_v2/8e4a137c42d0c7c09203a33fb5d7a29f.png',
#  'patches_256_v2/b31dfaee9eea1c99e77594827c283ac2.png',
#  'patches_256_v2/76861af21393eb21f6a9b4051125cc40.png',
#  'patches_256_v2/52d16b210fec8df750abaa022b9a2201.png',
#  'patches_256_v2/0ba13ca4f966af18a72dee6f0a40731f.png',
#  'patches_256_v2/e24b99affcb778a99d0c6c176fe2e537.png',
#  'patches_256_v2/2e55cd9c8c40394372d65318af20455d.png',
#  'patches_256_v2/9abda0d013f1ca1e3dd45c761d575093.png',
#  'patches_256_v2/0ee3c6487c6f5af10ab786722f07f078.png',
#  'patches_256_v2/24ca82c7ca91d99c8ff3effc807162fb.png',
#  'patches_256_v2/f15b05b3a01022482c4102f97b036ba8.png',
#  'patches_256_v2/69c315d47be048ebb7b13c6ddec721db.png',
#  'patches_256_v2/d90f8dfb68c6a27350cc6af5cf6b1f37.png',
#  'patches_256_v2/33be4aa027c44e80de2b4d4bcb926d46.png',
#  'patches_256_v2/7dee18733dadf1743c59fc8ee08803df.png',
#  'patches_256_v2/f888fbd624ad4aaf7ea646c30995fa3c.png',
#  'patches_256_v2/fdd0305f1ed738671d007c6e090349fc.png',
#  'patches_256_v2/8af38c895332badaa642af444209ea91.png',
#  'patches_256_v2/4fe0ee20e2d0f9c321e622712630966d.png',
#  'patches_256_v2/17e8082cade8092c2db1421971de2900.png',
#  'patches_256_v2/ee3c0d9c8e7e02953e8bc5e5bd3de2a6.png',
#  'patches_256_v2/262b7ea40a2ada4cf0c0fc861b9c4ce9.png',
#  'patches_256_v2/026b23a7838217f0808f754a0c8268bf.png',
#  'patches_256_v2/df2d2b0e294be368335e92bee28c1f0a.png',
#  'patches_256_v2/6685c9a77c6e830569f96de20a976f64.png',
#  'patches_256_v2/ef921d49d914dfec86bf3ff0bdcdf2e2.png',
#  'patches_256_v2/903b9ab912176218c5dfaa2eb1ef1fba.png',
#  'patches_256_v2/4f3430e9ece3184552cb6aea962d93f2.png',
#  'patches_256_v2/0077bd896792572379da86bd01c27869.png',
#  'patches_256_v2/cf0de6f62dbdcd190d8d7d1e2a845f06.png',
#  'patches_256_v2/e1615cbb67cc34cc9802fe993b5a9ce1.png',
#  'patches_256_v2/a0768f3354bed15bbb4c099275c95c6b.png',
#  'patches_256_v2/3fd72ae624a3d5f1f0901e92eb53e8b3.png',
#  'patches_256_v2/076723e22e3bce1b8f65e994ba531a32.png',
#  'patches_256_v2/c0e2a1e0171b296436d38002a6a3e9e0.png',
#  'patches_256_v2/98987022c4f37a5c5f4c3f593669f72d.png',
#  'patches_256_v2/76d971db7538f379e2e591c0bf714a4f.png',
#  'patches_256_v2/c63f55c2b8c4daa22e126be4efcb477b.png',
#  'patches_256_v2/0fecc919f31ded5527c6b62488f29283.png',
#  'patches_256_v2/94ec85db0cd39a6b6a2c77875daf9391.png',
#  'patches_256_v2/f0e34aa78a2f311f9f108a3514fbfcc7.png',
#  'patches_256_v2/72c26b7b68749d87354634e8c613bc4f.png',
#  'patches_256_v2/edefe1ad37c31b929ac00283a7f98b50.png',
#  'patches_256_v2/b7ab2abe27efeb8b6271dd1f892b8d2e.png',
#  'patches_256_v2/2b769eb1a11bab4c0c349e3be3c9f47c.png',
#  'patches_256_v2/8e25916d723b2339862ead3f5d956645.png',
#  'patches_256_v2/f124d495b3c6c7408ecb854851b72a1d.png',
#  'patches_256_v2/f7a3970e43e43e0b1ead86ecd9795173.png',
#  'patches_256_v2/46448cc47b403e1593168bd4674d701d.png',
#  'patches_256_v2/a07e5c47f85735a25bd1158f3f383c0c.png',
#  'patches_256_v2/b58591ce43d3f7d8d4b2a1bd0d52bea7.png',
#  'patches_256_v2/330171581a5a96bf9f57164e014d0d20.png',
#  'patches_256_v2/e4ba6c77b02ed48f98e8fd4f50e6f94d.png',
#  'patches_256_v2/5d54121dd60de37696e9d23245e76b05.png',
#  'patches_256_v2/a64d1f528a5d1955788481478aa2a11a.png',
#  'patches_256_v2/48d92741df69a47fcbff0598561759c0.png',
#  'patches_256_v2/48cacd6c119905d0b6110c3d0ba91b7b.png',
#  'patches_256_v2/2156f534b067da5eaf6e17c6b6c7874a.png',
#  'patches_256_v2/022709a179f14794640565d572323798.png',
#  'patches_256_v2/c3a2487b0509cf3f4227943620a281bc.png',
#  'patches_256_v2/00e5af5e94e262a465217cdc2cdbefc7.png',
#  'patches_256_v2/b3b1374837eed8c962d284b56a940ab8.png',
#  'patches_256_v2/2aa791b526d21eb84952017c9dbeec11.png',
#  'patches_256_v2/5bebe4b14a4180bf424d25f3514f1575.png',
#  'patches_256_v2/0e041941a88f43a196f949e70c1f1d49.png',
#  'patches_256_v2/ef68c4f85e08580a84d35559a784cbaf.png',
#  'patches_256_v2/60d12dc372e80640713aaf70325d65d5.png',
#  'patches_256_v2/011aa76edef6288b1646819846ed4eb2.png',
#  'patches_256_v2/c96581e0799ea4c3395fe52e9c80104b.png',
#  'patches_256_v2/e7d8352f97d682e2aa02a37df75ddc82.png',
#  'patches_256_v2/b35123ec732efd9298f2356acbbc6dec.png',
#  'patches_256_v2/d37322bd2943195e56efe08411a70d84.png',
#  'patches_256_v2/57a82dfdd1a323effd6142f4b535d549.png',
#  'patches_256_v2/a48ec9cf60458f45cf6d00615f9802a9.png',
#  'patches_256_v2/5891741baa026b2e329529d9a45f1027.png',
#  'patches_256_v2/87b58baea6e6d6b4d0452ce2d0cfb0bd.png',
#  'patches_256_v2/098ccfb58633c10a201bf619bdf02b63.png',
#  'patches_256_v2/bae542c64ab46998f4107552fc2184fb.png',
#  'patches_256_v2/988afa5cfc2ad2672e794def2e5e5c4f.png',
#  'patches_256_v2/19048a88bac88bdc2aaeac17de1d6110.png',
#  'patches_256_v2/3cbe82e3c9165ed34082a67b0dd8fac2.png',
#  'patches_256_v2/7eb8a9cfdbbd3400049c45859c5b8df9.png',
#  'patches_256_v2/1d1c863d677644c8af906eacf5bd4aab.png',
#  'patches_256_v2/a864698c576c5d73c6ca3aa07de56900.png',
#  'patches_256_v2/b75626233d36a7e67f026f1608bf7417.png',
#  'patches_256_v2/638733f2b49e0120bde7a0c496b8435a.png',
#  'patches_256_v2/0ec9dde6876af08d64bbf1aa3c71761c.png',
#  'patches_256_v2/87d0c9d78ecb841262d3a99c9aa1493f.png',
#  'patches_256_v2/c61e7b73e8b0fd91546bab50e468b268.png',
#  'patches_256_v2/3a153da8c3a92c6448f82bd6bcf6fc69.png',
#  'patches_256_v2/07869e863cf220552d8f95bb7865acb4.png',
#  'patches_256_v2/89e535af70b8164a8b3c2ec137d0d69d.png',
#  'patches_256_v2/7c5d18a053c0012f0530a0e15b22bed6.png',
#  'patches_256_v2/7ba650ad91eb34794737253e7c63ca23.png',
#  'patches_256_v2/450eeecf5a51e01d2387cc807dd4d46d.png',
#  'patches_256_v2/0033dfd8e667d6981cc39e1e7f69b01c.png',
#  'patches_256_v2/1a395c9be9cdd85efd0bbded51fc37ed.png',
#  'patches_256_v2/4ae79d75232baebb19418bb70233218f.png',
#  'patches_256_v2/5de291ea3089d376c8a4a5657905535e.png',
#  'patches_256_v2/38d3c1d4d757b361994f012f27a0a329.png',
#  'patches_256_v2/72ad88b5ee4d03449efb626d32fdf1de.png',
#  'patches_256_v2/a373db22300c996228fd7a3e924f7494.png',
#  'patches_256_v2/9f84c13221fb249ef550bafef185f89e.png',
#  'patches_256_v2/078c5412940c388a887b708c39e4ccdc.png',
#  'patches_256_v2/936bc8a730f84005cbf2ac8321e9f202.png',
#  'patches_256_v2/02d716304d04c284b1f0324d1b067fc0.png',
#  'patches_256_v2/637d92b6c21192a6548e231f455b844d.png',
#  'patches_256_v2/8ba2423107111230d98a0bc75ed38c66.png',
#  'patches_256_v2/444548d9020421ba638033b4631e0f35.png',
#  'patches_256_v2/701f287fc386c098c0b993387b546732.png',
#  'patches_256_v2/1a242e0314279a861564c77883292a31.png',
#  'patches_256_v2/2c98aed30c4a31ce9f09e0bb155eb47b.png',
#  'patches_256_v2/c679a578bf70e15c09533ce60b2d8e85.png',
#  'patches_256_v2/3ddf0ae8f9bc6f4de52357795e651ecc.png',
#  'patches_256_v2/21d74bd4e272fa019a202f6d23298ec9.png',
#  'patches_256_v2/09621177d687c8cf92a87e14e2d6f700.png',
#  'patches_256_v2/72a5033c62d28465020e4cb17bc88fbb.png',
#  'patches_256_v2/da381ef5d7192378b88eabe182c85322.png',
#  'patches_256_v2/35e7352003c9d548b5f083773c741a1b.png',
#  'patches_256_v2/ceac6b4da2b35562f1279c5eb1037b11.png',
#  'patches_256_v2/abd748b13ed8eb88734a522b3459b9ce.png',
#  'patches_256_v2/856d7e84846de3a7f3645bea8e8e5c6b.png',
#  'patches_256_v2/fe1c632b858fefb8bbe54d526627680d.png',
#  'patches_256_v2/bfa998192f8acebdae19c22ef9d99f00.png',
#  'patches_256_v2/475dad047c16962d7ff35e6ba54a0a5f.png',
#  'patches_256_v2/25f22f90ed1a42f9b3806a88f4103457.png',
#  'patches_256_v2/418388005b7e84fa114ecc49b8b11dd2.png',
#  'patches_256_v2/4f71e95dd778c23d88c1a1600e375a4f.png',
#  'patches_256_v2/24f96f46f8551945f559d12bd4573f7d.png',
#  ...]

# %%
from fastai.vision.all import *
from PIL import Image, ImageDraw
from random import randint

# %%
import wandb
from fastai.callback.wandb import *
wandb.init(project="ors_project", entity="android100")
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: android100 (use `wandb login --relogin` to force relogin)
# wandb version 0.12.14 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.12
# Run data is saved locally in <code>/home2/s.ranjan/ors-project/wandb/run-20220417_163225-3sjdsrch</code>
# Syncing run <strong><a href="https://wandb.ai/android100/ors_project/runs/3sjdsrch" target="_blank">volcanic-disco-9</a></strong> to <a href="https://wandb.ai/android100/ors_project" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/android100/ors_project/runs/3sjdsrch?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
plt.imshow(damaged_img_arr[:, :, 2], 'gray')

# %%
path = Path("/scratch/ors/")
path_clear = path/"clr"
path_damaged = path/"dmg"

# %%
LINE_WIDTH = 2
STRIP_IMAGE_SIZE = 512

# %%
def damage_image(image_path):    
    stripes_base = Image.new("RGB", (STRIP_IMAGE_SIZE, STRIP_IMAGE_SIZE), (255, 255, 255))
    stripes = ImageDraw.Draw(stripes_base)

    
    color = [255, 255, 255]
    color[random.randint(0, 2)] = 0
    color = tuple(color)

    for y in range(int(1.1 * LINE_WIDTH), int(STRIP_IMAGE_SIZE - 0.1 * LINE_WIDTH), 20):
        stripes.line([0, y, STRIP_IMAGE_SIZE, y], width=LINE_WIDTH, fill=color)
    
    damage_lines = stripes_base.rotate(random.randint(0, 360))
    damage_lines = damage_lines.crop(((STRIP_IMAGE_SIZE - 256)/2, (STRIP_IMAGE_SIZE - 256)/2, (STRIP_IMAGE_SIZE + 256)/2, (STRIP_IMAGE_SIZE + 256)/2, ))
    damage_lines = np.array(damage_lines) / 255
    
    img = Image.open(image_path)
    img = np.array(img) / 255
    damaged_img = img * damage_lines
    damaged_img = np.uint8(damaged_img * 255)
    damaged_img = Image.fromarray(damaged_img)
    damaged_img.save(path_damaged/image_path.name)

# %%
parallel(damage_image, path_clear.ls(), n_workers=8, progress=True)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# (#12900) [None,None,None,None,None,None,None,None,None,None...]

# %%
dblock = DataBlock(blocks=(ImageBlock, ImageBlock),
                  get_items=get_image_files,
                  get_y=lambda x: path_clear/x.name,
                  splitter=RandomSplitter(),
                  item_tfms=Resize(224),
                  batch_tfms=[*aug_transforms(max_zoom=2.),
                             Normalize.from_stats(*imagenet_stats)])

# %%
dls = dblock.dataloaders(path_damaged, bs=8)
# Out:
# /home2/s.ranjan/miniconda3/envs/ors/lib/python3.6/site-packages/torch/_tensor.py:1051: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   ret = func(*args, **kwargs)

# %%
dls_gen = dls
dls_gen.c = 3

# %%
dls_gen.show_batch()

# %%
wd, y_range, loss_gen = 1e-3, (-3., 3.), MSELossFlat()

# %%
bbone = resnet34
# cfg = unet_config(blur=True, norm_type=NormType.Weight, self_attention=True,
#                   y_range=y_range)

# %%
def create_gen_learner():
    return unet_learner(dls_gen, bbone, loss_func=loss_gen, cbs=WandbCallback())

# %%
learn_gen = create_gen_learner()

# %%
learn_gen.fit_one_cycle(15, pct_start=0.8, wd=wd)
# Out:
# WandbCallback requires use of "SaveModelCallback" to log best model
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.014197</td>
#       <td>0.021222</td>
#       <td>03:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.005415</td>
#       <td>0.010232</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.003971</td>
#       <td>0.005944</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.002597</td>
#       <td>0.003938</td>
#       <td>03:55</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.002532</td>
#       <td>0.002904</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.001669</td>
#       <td>0.002239</td>
#       <td>03:58</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.002219</td>
#       <td>0.002315</td>
#       <td>03:58</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.001648</td>
#       <td>0.001885</td>
#       <td>03:58</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.001466</td>
#       <td>0.001283</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.001460</td>
#       <td>0.001357</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.001144</td>
#       <td>0.001214</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.001288</td>
#       <td>0.001455</td>
#       <td>03:58</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000735</td>
#       <td>0.000838</td>
#       <td>03:58</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000443</td>
#       <td>0.000562</td>
#       <td>04:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000404</td>
#       <td>0.000549</td>
#       <td>03:58</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_gen.unfreeze()

# %%
learn_gen.fit_one_cycle(5, slice(1e-6,1e-3), wd=wd)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.000811</td>
#       <td>0.000936</td>
#       <td>04:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.000390</td>
#       <td>0.000525</td>
#       <td>04:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_gen.show_results(max_n=4, figsize=(12,12))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn_gen.save('image_restoration_single_band_damage')
# Out:
# Path('models/image_restoration_single_band_damage.pth')

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='199.423 MB of 199.423 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0,…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>eps_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eps_1</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eps_2</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_0</td><td>▁▁▁▂▂▂▂▃▃▃▄▄▅▅▆▆▆▇▇▇█████▇▅▄▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_1</td><td>▁▁▁▂▂▂▂▃▃▃▄▄▅▅▆▆▆▇▇▇█████▇▅▄▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_2</td><td>▁▁▁▁▂▂▂▃▃▃▄▄▅▅▆▆▆▇▇▇█████▇▅▄▂▁▅█▄▂▃█▇▆▃▁</td></tr><tr><td>mom_0</td><td>████▇▇▇▇▆▆▅▅▄▄▃▃▃▂▂▂▁▁▁▁▁▂▄▅▇█▄▁▅▇▆▁▂▃▆█</td></tr><tr><td>mom_1</td><td>████▇▇▇▇▆▆▅▅▄▄▃▃▃▂▂▂▁▁▁▁▁▂▄▅▇█▄▁▅▇▆▁▂▃▆█</td></tr><tr><td>mom_2</td><td>████▇▇▇▇▆▆▅▅▄▄▃▃▃▂▂▂▁▁▁▁▁▂▄▅▇█▄▁▅▇▆▁▂▃▆█</td></tr><tr><td>raw_loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sqr_mom_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sqr_mom_1</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sqr_mom_2</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>wd_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>wd_1</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>wd_2</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>eps_0</td><td>1e-05</td></tr><tr><td>eps_1</td><td>1e-05</td></tr><tr><td>eps_2</td><td>1e-05</td></tr><tr><td>lr_0</td><td>0.0</td></tr><tr><td>lr_1</td><td>0.0</td></tr><tr><td>lr_2</td><td>0.0</td></tr><tr><td>mom_0</td><td>0.95</td></tr><tr><td>mom_1</td><td>0.95</td></tr><tr><td>mom_2</td><td>0.95</td></tr><tr><td>raw_loss</td><td>0.00025</td></tr><tr><td>sqr_mom_0</td><td>0.99</td></tr><tr><td>sqr_mom_1</td><td>0.99</td></tr><tr><td>sqr_mom_2</td><td>0.99</td></tr><tr><td>train_loss</td><td>0.00032</td></tr><tr><td>valid_loss</td><td>0.00049</td></tr><tr><td>wd_0</td><td>0.001</td></tr><tr><td>wd_1</td><td>0.001</td></tr><tr><td>wd_2</td><td>0.001</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">volcanic-disco-9</strong>: <a href="https://wandb.ai/android100/ors_project/runs/3sjdsrch" target="_blank">https://wandb.ai/android100/ors_project/runs/3sjdsrch</a><br/>Synced 6 W&B file(s), 2160 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220417_163225-3sjdsrch/logs</code>
